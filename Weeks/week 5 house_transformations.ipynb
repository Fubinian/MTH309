# %% [markdown]
# ### Execute the cell below before proceeding.
#
# The code in this cell will download file with a Python script from the Internet. Make sure that you have a network connection before executing it.

# %%
import requests
with open("house_transformations.py", 'w') as foo:
    foo.write(requests.get("https://git.io/fjNde").text)
from house_transformations import *

# %% [markdown]
# <br/>
#
# # House Transformations
#
# The function `matrix_t()` shows the effect of a matrix transformation $T_A\colon {\mathbb R}^2 \to {\mathbb R}^2$ given by $T_A({\mathbf v}) = A{\mathbf v}$, where $A$ is a 2$\times$2 matrix.

# %% [markdown]
# Enter a 2$\times$2 matrix $A$:

# %%
A = Matrix([[-1, 1], [2, 3]])
A
# Out:
# ⎡-1  1⎤
# ⎢     ⎥
# ⎣2   3⎦

# %% [markdown]
# The next cell produces a picture demonstrating the effect of the linear transformation $T_A$. The image on the left shows a drawing of a house. The image of the right shows that same drawing after the transformation $T_A$ is applied to it. You can use controls above the picture to pan and zoom on it.

# %%
matrix_t(A)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="8d37ac0e-e0a8-47a1-9abb-50d5e8477ec8">Loading BokehJS ...</span>
#     </div>
# <div class="bk-root">
#     <div class="bk-plotdiv" id="6b085a36-2c81-45fc-8a0c-66f76676bdf0"></div>
# </div>

# %% [markdown]
# ## Exercises.
#
# In each exercise below find a $2\times 2$ matrix $A$ such that the matrix transformation
# $$T_A \colon {\mathbb R}^2 \to  {\mathbb R}^2 $$
# transforms the image as indicated. Plug in this matrix into the function `matrix_t()` to recreate the picture accompanying the exercise. To complete this assignment enter matrices you used in each part into UBx.
#
# <hr><hr>

# %% [markdown]
# ### Exercise 1.
#
# The transformation $T_A$ magnifies the image by the factor of 2:

# %%
# execute this cell to see the picture
show_pic("scale2")
# Out:
#         <iframe
#             width="800"
#             height="410"
#             src="https://bbadzioch.github.io/MTH309_F2019/house_transformations_pics/scale2.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# ### Solution:

# %%
B = Matrix([[2,0],[0,2]])
B
# Out:
# ⎡2  0⎤
# ⎢    ⎥
# ⎣0  2⎦

# %%
matrix_t(B)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="49af3e16-e4a5-4c5c-9dec-e4c0573efc3a">Loading BokehJS ...</span>
#     </div>
# <div class="bk-root">
#     <div class="bk-plotdiv" id="1055e180-0734-422a-8612-b3eab8141f31"></div>
# </div>

# %% [markdown]
# <br/>
# <hr>
#
# ### Exercise 2.
#
# The transformation $T_A$ reflect the image with respect to the $x$-axis:

# %%
# execute this cell to see the picture
show_pic("ref_x")
# Out:
#         <iframe
#             width="800"
#             height="410"
#             src="https://bbadzioch.github.io/MTH309_F2019/house_transformations_pics/ref_x.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# ### Solution:

# %%
C = Matrix([[1,0],[0,-1]])
C
# Out:
# ⎡1  0 ⎤
# ⎢     ⎥
# ⎣0  -1⎦

# %%
matrix_t(C)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="e42c2e67-9dd3-4c27-a9bb-f583e03c610c">Loading BokehJS ...</span>
#     </div>
# <div class="bk-root">
#     <div class="bk-plotdiv" id="c14b133f-3735-4993-abd2-d12cb7484f4b"></div>
# </div>

# %% [markdown]
# <br/>
# <hr>
#
# ### Exercise 3.
#
# The transformation $T_A$ reflect the image with respect to the $y$-axis:

# %%
# execute this cell to see the picture
show_pic("ref_y")
# Out:
#         <iframe
#             width="800"
#             height="410"
#             src="https://bbadzioch.github.io/MTH309_F2019/house_transformations_pics/ref_y.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# ### Solution:

# %%
D = Matrix([[-1,0],[0,1]])
D
# Out:
# ⎡-1  0⎤
# ⎢     ⎥
# ⎣0   1⎦

# %%
matrix_t(D)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1a04f663-5340-4c69-bda2-1f12e017d4d3">Loading BokehJS ...</span>
#     </div>
# <div class="bk-root">
#     <div class="bk-plotdiv" id="012dda76-220b-4cb0-8282-ca6a1e8cb92a"></div>
# </div>

# %% [markdown]
# <br/>
# <hr>
#
# ### Exercise 4.
#
# The transformation $T_A$ reflect the image with respect to the origin of the coordinate system:

# %%
# execute this cell to see the picture
show_pic("ref_orig")
# Out:
#         <iframe
#             width="800"
#             height="410"
#             src="https://bbadzioch.github.io/MTH309_F2019/house_transformations_pics/ref_orig.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# ### Solution:

# %%
E = Matrix([[-1,0],[0,-1]])
E
# Out:
# ⎡-1  0 ⎤
# ⎢      ⎥
# ⎣0   -1⎦

# %%
matrix_t(E)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="774428bb-221f-49dc-984c-e7dbe0bd985f">Loading BokehJS ...</span>
#     </div>
# <div class="bk-root">
#     <div class="bk-plotdiv" id="eac2e12f-4c09-478d-9e58-edf810ca60b5"></div>
# </div>

# %% [markdown]
# <br/>
# <hr>
#
# ### Exercise 5.
#
# The transformation $T_A$ rotates the image 90 degrees clockwise:

# %%
# execute this cell to see the picture
show_pic("rot_plus90")
# Out:
#         <iframe
#             width="800"
#             height="410"
#             src="https://bbadzioch.github.io/MTH309_F2019/house_transformations_pics/rot_plus90.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# ### Solution:

# %%
F = Matrix([[0,-1],[1,0]])
F
# Out:
# ⎡0  -1⎤
# ⎢     ⎥
# ⎣1  0 ⎦

# %%
matrix_t(F)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="808a76dc-c17b-48d1-9183-d6977eb903c8">Loading BokehJS ...</span>
#     </div>
# <div class="bk-root">
#     <div class="bk-plotdiv" id="53514f04-718a-44a0-8d20-df08918e5fe1"></div>
# </div>

# %% [markdown]
# <br/>
# <hr>
#
# ### Exercise 6.
#
# The transformation $T_A$ rotates the image 45 degrees counterclockwise:

# %%
# execute this cell to see the picture
show_pic("rot_minus45")
# Out:
#         <iframe
#             width="800"
#             height="410"
#             src="https://bbadzioch.github.io/MTH309_F2019/house_transformations_pics/rot_minus45.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# ### Solution:

# %%
G = Matrix([[sqrt(2)/2,sqrt(2)/2],[-sqrt(2)/2,sqrt(2)/2]])
G
# Out:
# ⎡ √2   √2⎤
# ⎢ ──   ──⎥
# ⎢ 2    2 ⎥
# ⎢        ⎥
# ⎢-√2   √2⎥
# ⎢────  ──⎥
# ⎣ 2    2 ⎦

# %%
matrix_t(G)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="83166a9b-f535-4317-b812-ab23f39044db">Loading BokehJS ...</span>
#     </div>
# <div class="bk-root">
#     <div class="bk-plotdiv" id="6a3d7140-1d4b-48eb-9542-458fd5a94651"></div>
# </div>

# %% [markdown]
# <br/>
# <hr>
#
#
# ### Exercise 7.
#
# The transformation $T_A$ deforms the image as follows:

# %%
# execute this cell to see the picture
show_pic("skew1")
# Out:
#         <iframe
#             width="800"
#             height="410"
#             src="https://bbadzioch.github.io/MTH309_F2019/house_transformations_pics/skew1.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
H = Matrix([[1,-2],[0,2]])
H
# Out:
# ⎡1  -2⎤
# ⎢     ⎥
# ⎣0  2 ⎦

# %%
matrix_t(H)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="49d197de-7660-48b5-af8c-b2ecf6312cef">Loading BokehJS ...</span>
#     </div>
# <div class="bk-root">
#     <div class="bk-plotdiv" id="f9dacead-7e2d-4e91-bed9-2a54280874a1"></div>
# </div>

# %% [markdown]
# <br/>
# <hr>
#
# ### Exercise 8.
#
# The transformation $T_A$ deforms the image as follows:

# %%
# execute this cell to see the picture
show_pic("skew2")
# Out:
#         <iframe
#             width="800"
#             height="410"
#             src="https://bbadzioch.github.io/MTH309_F2019/house_transformations_pics/skew2.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# ### Solution:

# %%
I = Matrix([[-4,-3],[4,-1]])
I
# Out:
# ⎡-4  -3⎤
# ⎢      ⎥
# ⎣4   -1⎦

# %%
matrix_t(I)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="0398e95f-939a-4fe8-9d81-e52c0401b73c">Loading BokehJS ...</span>
#     </div>
# <div class="bk-root">
#     <div class="bk-plotdiv" id="e32239da-a7de-49e2-85ef-36f19498d120"></div>
# </div>
